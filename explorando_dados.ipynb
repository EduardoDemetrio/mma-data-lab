# %%
import pandas as pd
import numpy as np 
import hashlib

# %% [markdown]
# ## Dados

# %% [markdown]
# ### `Analise das fontes de dados:`
# _____________________________________
# _____________________________________

# %% [markdown]
# ### Scrape ufc stats

# %%
event_details = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\1.scrape_ufc_stats\event_details.csv')
fight_details = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\1.scrape_ufc_stats\fight_details.csv')
fight_results = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\1.scrape_ufc_stats\fight_results.csv')
fight_stats = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\1.scrape_ufc_stats\fight_stats.csv')
fighter_details = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\1.scrape_ufc_stats\fighter_details.csv')
fighter_tott = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\1.scrape_ufc_stats\fighter_tott.csv')

# %%
display(event_details)
display(fight_details[fight_details['event_name']=='UFC Fight Night: Allen vs. Costa'])
display(fight_results[fight_results['event_name']=='UFC Fight Night: Allen vs. Costa'])
display(fight_stats[fight_stats['event_name']=='UFC Fight Night: Allen vs. Costa'])
# display(fighter_details)
display(fighter_tott[fighter_tott['fighter_name'].isin(['Arnold Allen','Melquizael Costa'])])
# Out:
#                                       event_name  \
# 0               UFC Fight Night: Allen vs. Costa
# 1                UFC 328: Chimaev vs. Strickland
# 2    UFC Fight Night: Della Maddalena vs. Prates
# 3            UFC Fight Night: Sterling vs. Zalal
# 4              UFC Fight Night: Burns vs. Malott
# ..                                           ...
# 769                   UFC 6: Clash of the Titans
# 770               UFC 5: The Return of the Beast
# 771               UFC 4: Revenge of the Warriors
# 772                    UFC 3: The American Dream
# 773                            UFC 2: No Way Out
#
#                                                    url  event_date  \
# 0    http://ufcstats.com/event-details/73abb7a5c57f...  2026-05-16
# 1    http://ufcstats.com/event-details/9eedac48b497...  2026-05-09
# 2    http://ufcstats.com/event-details/872b018076f8...  2026-05-02
# 3    http://ufcstats.com/event-details/e60d773a0a42...  2026-04-25
# 4    http://ufcstats.com/event-details/c3ac8d0da7b0...  2026-04-18
# ..                                                 ...         ...
# 769  http://ufcstats.com/event-details/1c3f5e85b59e...  1995-07-14
# 770  http://ufcstats.com/event-details/dedc3bb440d0...  1995-04-07
# 771  http://ufcstats.com/event-details/b60391da771d...  1994-12-16
# 772  http://ufcstats.com/event-details/1a49e0670dfa...  1994-09-09
# 773  http://ufcstats.com/event-details/a6a9ab5a824e...  1994-03-11
#
#                           event_location
# 0                 Las Vegas, Nevada, USA
# 1                Newark, New Jersey, USA
# 2    Perth, Western Australia, Australia
# 3                 Las Vegas, Nevada, USA
# 4             Winnipeg, Manitoba, Canada
# ..                                   ...
# 769                 Casper, Wyoming, USA
# 770       Charlotte, North Carolina, USA
# 771                 Tulsa, Oklahoma, USA
# 772       Charlotte, North Carolina, USA
# 773                Denver, Colorado, USA
#
# [774 rows x 4 columns]
#                           event_name  \
# 0   UFC Fight Night: Allen vs. Costa
# 1   UFC Fight Night: Allen vs. Costa
# 2   UFC Fight Night: Allen vs. Costa
# 3   UFC Fight Night: Allen vs. Costa
# 4   UFC Fight Night: Allen vs. Costa
# 5   UFC Fight Night: Allen vs. Costa
# 6   UFC Fight Night: Allen vs. Costa
# 7   UFC Fight Night: Allen vs. Costa
# 8   UFC Fight Night: Allen vs. Costa
# 9   UFC Fight Night: Allen vs. Costa
# 10  UFC Fight Night: Allen vs. Costa
# 11  UFC Fight Night: Allen vs. Costa
# 12  UFC Fight Night: Allen vs. Costa
#
#                                         bout  \
# 0          Arnold Allen vs. Melquizael Costa
# 1               Dooho Choi vs. Daniel Santos
# 2            Malcolm Wellmaker vs. Juan Diaz
# 3   Modestas Bukauskas vs. Christian Edwards
# 4             Timmy Cuamba vs. Benardo Sopaj
# 5    Nikolay Veretennikov vs. Khaos Williams
# 6                Tuco Tokkos vs. Ivan Erslan
# 7                Tommy Gantt vs. Artur Minev
# 8    Ketlen Vieira vs. Jacqueline Cavalcanti
# 9           Cody Brundage vs. Andre Petroski
# 10          Alice Ardelean vs. Polyana Viana
# 11              Daniel Barez vs. Luis Gurule
# 12         Shauna Bannon vs. Nicolle Caliari
#
#                                                   url
# 0   http://ufcstats.com/fight-details/e4aa60812489...
# 1   http://ufcstats.com/fight-details/fc1266e2892e...
# 2   http://ufcstats.com/fight-details/ecb7ff543dd4...
# 3   http://ufcstats.com/fight-details/57bd683efc79...
# 4   http://ufcstats.com/fight-details/a6ec8573a9d3...
# 5   http://ufcstats.com/fight-details/ec32745308e2...
# 6   http://ufcstats.com/fight-details/6242cda790f2...
# 7   http://ufcstats.com/fight-details/c9e0aa88afb8...
# 8   http://ufcstats.com/fight-details/5f7111b982bc...
# 9   http://ufcstats.com/fight-details/48cb604345f1...
# 10  http://ufcstats.com/fight-details/b98ead4eff6b...
# 11  http://ufcstats.com/fight-details/b482d4452e4d...
# 12  http://ufcstats.com/fight-details/39417b7d07c2...
#                           event_name  \
# 0   UFC Fight Night: Allen vs. Costa
# 1   UFC Fight Night: Allen vs. Costa
# 2   UFC Fight Night: Allen vs. Costa
# 3   UFC Fight Night: Allen vs. Costa
# 4   UFC Fight Night: Allen vs. Costa
# 5   UFC Fight Night: Allen vs. Costa
# 6   UFC Fight Night: Allen vs. Costa
# 7   UFC Fight Night: Allen vs. Costa
# 8   UFC Fight Night: Allen vs. Costa
# 9   UFC Fight Night: Allen vs. Costa
# 10  UFC Fight Night: Allen vs. Costa
# 11  UFC Fight Night: Allen vs. Costa
# 12  UFC Fight Night: Allen vs. Costa
#
#                                         bout outcome  \
# 0          Arnold Allen vs. Melquizael Costa     W/L
# 1               Dooho Choi vs. Daniel Santos     W/L
# 2            Malcolm Wellmaker vs. Juan Diaz     L/W
# 3   Modestas Bukauskas vs. Christian Edwards     W/L
# 4             Timmy Cuamba vs. Benardo Sopaj     L/W
# 5    Nikolay Veretennikov vs. Khaos Williams     L/W
# 6                Tuco Tokkos vs. Ivan Erslan     L/W
# 7                Tommy Gantt vs. Artur Minev     W/L
# 8    Ketlen Vieira vs. Jacqueline Cavalcanti     W/L
# 9           Cody Brundage vs. Andre Petroski     W/L
# 10          Alice Ardelean vs. Polyana Viana     W/L
# 11              Daniel Barez vs. Luis Gurule     L/W
# 12         Shauna Bannon vs. Nicolle Caliari     L/W
#
#                  weight_class                method  round  time  \
# 0          Featherweight Bout  Decision - Unanimous      5  5:00
# 1          Featherweight Bout                KO/TKO      2  4:29
# 2           Bantamweight Bout            Submission      2  4:08
# 3           Catch Weight Bout      Decision - Split      3  5:00
# 4           Bantamweight Bout            Submission      2  2:25
# 5           Welterweight Bout                KO/TKO      1  3:31
# 6      Light Heavyweight Bout  Decision - Unanimous      3  5:00
# 7            Lightweight Bout                KO/TKO      2  2:51
# 8   Women's Bantamweight Bout  Decision - Unanimous      3  5:00
# 9           Middleweight Bout                KO/TKO      2  0:44
# 10   Women's Strawweight Bout            Submission      2  4:36
# 11             Flyweight Bout  Decision - Unanimous      3  5:00
# 12   Women's Strawweight Bout            Submission      3  3:08
#
#           time_format        referee  \
# 0   5 Rnd (5-5-5-5-5)  Chris Tognoni
# 1       3 Rnd (5-5-5)   Kerry Hatley
# 2       3 Rnd (5-5-5)   Eric McMahon
# 3       3 Rnd (5-5-5)   Kerry Hatley
# 4       3 Rnd (5-5-5)    Jerin Valel
# 5       3 Rnd (5-5-5)  Chris Tognoni
# 6       3 Rnd (5-5-5)   Eric McMahon
# 7       3 Rnd (5-5-5)   Kerry Hatley
# 8       3 Rnd (5-5-5)    Jerin Valel
# 9       3 Rnd (5-5-5)  Chris Tognoni
# 10      3 Rnd (5-5-5)   Eric McMahon
# 11      3 Rnd (5-5-5)    Jerin Valel
# 12      3 Rnd (5-5-5)   Kerry Hatley
#
#                                               details  \
# 0   Eric Colon 45 - 50.David Lethaby 45 - 50.Sal D...
# 1                           Punch to Body At Distance
# 2                                    Rear Naked Choke
# 3   David Sutherland 28 - 29.Junichiro Kamijo 29 -...
# 4                                    Rear Naked Choke
# 5                         Punches to Head At Distance
# 6   Adalaide Byrd 28 - 29.Junichiro Kamijo 28 - 29...
# 7                   Punches to Head From Back Control
# 8   Eric Colon 28 - 29.Sal D'amato 28 - 29.David L...
# 9                          Punches to Head From Guard
# 10                 Calf Slicer From GuardCapsule lock
# 11  Eric Colon 27 - 30.Junichiro Kamijo 27 - 30.To...
# 12                     Arm Triangle From Side Control
#
#                                                   url  round_number
# 0   http://ufcstats.com/fight-details/e4aa60812489...             5
# 1   http://ufcstats.com/fight-details/fc1266e2892e...             2
# 2   http://ufcstats.com/fight-details/ecb7ff543dd4...             2
# 3   http://ufcstats.com/fight-details/57bd683efc79...             3
# 4   http://ufcstats.com/fight-details/a6ec8573a9d3...             2
# 5   http://ufcstats.com/fight-details/ec32745308e2...             1
# 6   http://ufcstats.com/fight-details/6242cda790f2...             3
# 7   http://ufcstats.com/fight-details/c9e0aa88afb8...             2
# 8   http://ufcstats.com/fight-details/5f7111b982bc...             3
# 9   http://ufcstats.com/fight-details/48cb604345f1...             2
# 10  http://ufcstats.com/fight-details/b98ead4eff6b...             2
# 11  http://ufcstats.com/fight-details/b482d4452e4d...             3
# 12  http://ufcstats.com/fight-details/39417b7d07c2...             3
#                           event_name                               bout  \
# 0   UFC Fight Night: Allen vs. Costa  Arnold Allen vs. Melquizael Costa
# 1   UFC Fight Night: Allen vs. Costa  Arnold Allen vs. Melquizael Costa
# 2   UFC Fight Night: Allen vs. Costa  Arnold Allen vs. Melquizael Costa
# 3   UFC Fight Night: Allen vs. Costa  Arnold Allen vs. Melquizael Costa
# 4   UFC Fight Night: Allen vs. Costa  Arnold Allen vs. Melquizael Costa
# ..                               ...                                ...
# 61  UFC Fight Night: Allen vs. Costa  Shauna Bannon vs. Nicolle Caliari
# 62  UFC Fight Night: Allen vs. Costa  Shauna Bannon vs. Nicolle Caliari
# 63  UFC Fight Night: Allen vs. Costa  Shauna Bannon vs. Nicolle Caliari
# 64  UFC Fight Night: Allen vs. Costa  Shauna Bannon vs. Nicolle Caliari
# 65  UFC Fight Night: Allen vs. Costa  Shauna Bannon vs. Nicolle Caliari
#
#       round     fighter_name  knockdowns   sig_str sig_str_pct total_str  \
# 0   Round 1     Arnold Allen         1.0    9 of 9        100%  18 of 20
# 1   Round 2     Arnold Allen         0.0  23 of 38         60%  28 of 44
# 2   Round 3     Arnold Allen         0.0  32 of 52         61%  44 of 66
# 3   Round 4     Arnold Allen         0.0  23 of 36         63%  26 of 41
# 4   Round 5     Arnold Allen         0.0  11 of 17         64%  40 of 51
# ..      ...              ...         ...       ...         ...       ...
# 61  Round 2    Shauna Bannon         0.0  20 of 28         71%  64 of 76
# 62  Round 3    Shauna Bannon         0.0   7 of 14         50%  12 of 19
# 63  Round 1  Nicolle Caliari         0.0    6 of 9         66%  25 of 28
# 64  Round 2  Nicolle Caliari         0.0   6 of 14         42%  10 of 18
# 65  Round 3  Nicolle Caliari         0.0   8 of 15         53%  15 of 22
#
#    takedowns takedown_pct  ...  body_str_landed  body_str_attempted  \
# 0     2 of 2         100%  ...              0.0                 0.0
# 1     0 of 0          NaN  ...              2.0                 2.0
# 2     0 of 0          NaN  ...              2.0                 2.0
# 3     1 of 1         100%  ...              1.0                 1.0
# 4     4 of 4         100%  ...              1.0                 2.0
# ..       ...          ...  ...              ...                 ...
# 61    0 of 0          NaN  ...              7.0                 8.0
# 62    0 of 1           0%  ...              2.0                 3.0
# 63    2 of 2         100%  ...              1.0                 1.0
# 64    1 of 6          16%  ...              1.0                 1.0
# 65    1 of 1         100%  ...              0.0                 1.0
#
#    leg_str_landed leg_str_attempted distance_str_landed  \
# 0             1.0               1.0                 4.0
# 1             5.0               5.0                23.0
# 2             3.0               3.0                25.0
# 3             2.0               2.0                23.0
# 4             0.0               0.0                 4.0
# ..            ...               ...                 ...
# 61            0.0               2.0                10.0
# 62            3.0               3.0                 7.0
# 63            0.0               0.0                 4.0
# 64            0.0               0.0                 1.0
# 65            0.0               0.0                 3.0
#
#    distance_str_attempted clinch_str_landed clinch_str_attempted  \
# 0                     4.0               0.0                  0.0
# 1                    38.0               0.0                  0.0
# 2                    45.0               0.0                  0.0
# 3                    35.0               0.0                  1.0
# 4                     9.0               0.0                  1.0
# ..                    ...               ...                  ...
# 61                   17.0               1.0                  2.0
# 62                   14.0               0.0                  0.0
# 63                    7.0               0.0                  0.0
# 64                    9.0               1.0                  1.0
# 65                   10.0               1.0                  1.0
#
#    ground_str_landed  ground_str_attempted
# 0                5.0                   5.0
# 1                0.0                   0.0
# 2                7.0                   7.0
# 3                0.0                   0.0
# 4                7.0                   7.0
# ..               ...                   ...
# 61               9.0                   9.0
# 62               0.0                   0.0
# 63               2.0                   2.0
# 64               4.0                   4.0
# 65               4.0                   4.0
#
# [66 rows x 41 columns]
#          fighter_name  height    weight reach    stance date_of_birth  \
# 85       Arnold Allen   5' 8"  145 lbs.   70"  Southpaw    1994-01-22
# 782  Melquizael Costa  5' 10"  145 lbs.   71"  Southpaw    1996-09-14
#
#                                                    url  height_cm  weight_lbs  \
# 85   http://ufcstats.com/fighter-details/040a74bb0a...     172.72       145.0
# 782  http://ufcstats.com/fighter-details/20bccc9bb4...     177.80       145.0
#
#      reach_inches  reach_cm
# 85           70.0    177.80
# 782          71.0    180.34

# %% [markdown]
# ### Fonte de dados
# - Local: C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\scrape_ufc_stats.
# - Origem: scraping disponível em https://github.com/Greco1899/scrape_ufc_stats (ufcstats).
# - Período coberto: eventos de 1994-03 até 2026-05.

# %% [markdown]
# ______________
# ### UFC datasets

# %%
ufc_dataset = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\ufc_datasets\ufc.csv')

# %%
display(
    ufc_dataset[
        ufc_dataset["fight_id"] =='3ce96bb0c69b39be'
    ]
)
# Out:
#              event_id                           event_name        date  \
# 730  899eaba48fa864a6  UFC Fight Night: Allen vs. Curtis 2  2024-04-06
#
#                    location          fight_id      division  title_fight  \
# 730  Las Vegas, Nevada, USA  3ce96bb0c69b39be  middleweight            0
#
#                method  finish_round  match_time_sec  ...  blue_td_avg  \
# 730  Decision - Split             5             300  ...          0.0
#
#     blue_td_avg_acc blue_td_def blue_sub_avg         winner         winner_id  \
# 730               0          82          0.0  Brendan Allen  2f181c0467965b98
#
#      red_weight_lbs  red_reach_inches  blue_weight_lbs  blue_reach_inches
# 730           83.91             190.5            77.11              190.5
#
# [1 rows x 128 columns]

# %%
print(
    ufc_dataset[
        ufc_dataset["fight_id"] == "3ce96bb0c69b39be"
    ].to_json(orient="records", indent=2, force_ascii=False)
)
# Out:
# [
#   {
#     "event_id":"899eaba48fa864a6",
#     "event_name":"UFC Fight Night: Allen vs. Curtis 2",
#     "date":"2024-04-06",
#     "location":"Las Vegas, Nevada, USA",
#     "fight_id":"3ce96bb0c69b39be",
#     "division":"middleweight",
#     "title_fight":0,
#     "method":"Decision - Split",
#     "finish_round":5,
#     "match_time_sec":300,
#     "total_rounds":5.0,
#     "referee":"Mark Smith",
#     "red_name":"Brendan Allen",
#     "red_id":"2f181c0467965b98",
#     "red_kd":0.0,
#     "red_sig_str_landed":112.0,
#     "red_sig_str_atmpted":222.0,
#     "red_sig_str_acc":50.0,
#     "red_total_str_landed":128.0,
#     "red_total_str_atmpted":242.0,
#     "red_total_str_acc":53.0,
#     "red_td_landed":6.0,
#     "red_td_atmpted":13.0,
#     "red_td_acc":46.0,
#     "red_sub_att":0.0,
#     "red_ctrl":365.0,
#     "red_head_landed":72.0,
#     "red_head_atmpted":172.0,
#     "red_head_acc":42.0,
#     "red_body_landed":25.0,
#     "red_body_atmpted":34.0,
#     "red_body_acc":74.0,
#     "red_leg_landed":15.0,
#     "red_leg_atmpted":16.0,
#     "red_leg_acc":94.0,
#     "red_dist_landed":108.0,
#     "red_dist_atmpted":214.0,
#     "red_dist_acc":50.0,
#     "red_clinch_landed":4.0,
#     "red_clinch_atmpted":8.0,
#     "red_clinch_acc":50.0,
#     "red_ground_landed":0.0,
#     "red_ground_atmpted":0.0,
#     "red_ground_acc":null,
#     "red_landed_head_per":64.0,
#     "red_landed_body_per":22.0,
#     "red_landed_leg_per":13.0,
#     "red_landed_dist_per":96.0,
#     "red_landed_clinch_per":3.0,
#     "red_landed_ground_per":0.0,
#     "red_nick_name":"All In",
#     "red_wins":25,
#     "red_losses":7,
#     "red_draws":0,
#     "red_height":187.96,
#     "red_weight":83.91,
#     "red_reach":190.5,
#     "red_stance":"Orthodox",
#     "red_dob":"1995\/12\/28",
#     "red_splm":3.85,
#     "red_str_acc":53,
#     "red_sapm":3.96,
#     "red_str_def":47,
#     "red_td_avg":1.65,
#     "red_td_avg_acc":41,
#     "red_td_def":56,
#     "red_sub_avg":1.2,
#     "blue_name":"Chris Curtis",
#     "blue_id":"5442f1bc4b47eaf3",
#     "blue_kd":0.0,
#     "blue_sig_str_landed":124.0,
#     "blue_sig_str_atmpted":241.0,
#     "blue_sig_str_acc":51.0,
#     "blue_total_str_landed":141.0,
#     "blue_total_str_atmpted":261.0,
#     "blue_total_str_acc":54.0,
#     "blue_td_landed":0.0,
#     "blue_td_atmpted":0.0,
#     "blue_td_acc":null,
#     "blue_sub_att":0.0,
#     "blue_ctrl":78.0,
#     "blue_head_landed":96.0,
#     "blue_head_atmpted":205.0,
#     "blue_head_acc":47.0,
#     "blue_body_landed":25.0,
#     "blue_body_atmpted":33.0,
#     "blue_body_acc":76.0,
#     "blue_leg_landed":3.0,
#     "blue_leg_atmpted":3.0,
#     "blue_leg_acc":100.0,
#     "blue_dist_landed":122.0,
#     "blue_dist_atmpted":237.0,
#     "blue_dist_acc":51.0,
#     "blue_clinch_landed":2.0,
#     "blue_clinch_atmpted":4.0,
#     "blue_clinch_acc":50.0,
#     "blue_ground_landed":0.0,
#     "blue_ground_atmpted":0.0,
#     "blue_ground_acc":null,
#     "blue_landed_head_per":77.0,
#     "blue_landed_body_per":20.0,
#     "blue_landed_leg_per":2.0,
#     "blue_landed_dist_per":98.0,
#     "blue_landed_clinch_per":1.0,
#     "blue_landed_ground_per":0.0,
#     "blue_nick_name":"Action-Man",
#     "blue_wins":32,
#     "blue_losses":12,
#     "blue_draws":0,
#     "blue_height":177.8,
#     "blue_weight":77.11,
#     "blue_reach":190.5,
#     "blue_stance":"Orthodox",
#     "blue_dob":"1987\/07\/15",
#     "blue_splm":5.98,
#     "blue_str_acc":50,
#     "blue_sapm":6.19,
#     "blue_str_def":54,
#     "blue_td_avg":0.0,
#     "blue_td_avg_acc":0,
#     "blue_td_def":82,
#     "blue_sub_avg":0.0,
#     "winner":"Brendan Allen",
#     "winner_id":"2f181c0467965b98",
#     "red_weight_lbs":83.91,
#     "red_reach_inches":190.5,
#     "blue_weight_lbs":77.11,
#     "blue_reach_inches":190.5
#   }
# ]

# %% [markdown]
# ### Fonte de dados
# - Local: C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\ufc_datasets
# - Origem: Keagle - kaggle.com/datasets/neelagiriaditya/ufc-datasets-1994-2025
# - Período coberto: eventos de 1994-03 até 2025-09.
#
#
# #### Resumo
# Temos uma basee que centraliza todas as informações nomeda como ufc.csv

# %% [markdown]
# ______________
# ### UFC datalabs

# %%
merged_stats_n_scorecards = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\3.ufc_datalab\merged_stats_n_scorecards.csv')
raw_fighter_details = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\3.ufc_datalab\raw_fighter_details.csv')
scorecards = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\3.ufc_datalab\scorecards.csv')
stats_processed_all_bouts = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\3.ufc_datalab\stats_processed_all_bouts.csv')
stats_processed = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\3.ufc_datalab\stats_processed.csv')
stats_raw = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\3.ufc_datalab\stats_raw.csv')
# Out:
# C:\Users\edude\AppData\Local\Temp\ipykernel_8512\63130270.py:1: DtypeWarning: Columns (60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_stats_n_scorecards = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\3.ufc_datalab\merged_stats_n_scorecards.csv')

# %%
display(merged_stats_n_scorecards[merged_stats_n_scorecards["event_name"] == "UFC Fight Night: Fiziev vs. Torres"])
display(raw_fighter_details)
display(stats_processed[stats_processed['event_name']== "UFC Fight Night: Fiziev vs. Torres"])
display(stats_raw)
# Out:
#           red_fighter_name     blue_fighter_name  event_date  \
# 0   ABDUL RAKHMAN YAKHYAEV         JULIUS WALKER  2026-06-27
# 1           ABUS MAGOMEDOV   MICHAL OLEKSIEJCZUK  2026-06-27
# 2            ASU ALMABAYEV       CHARLES JOHNSON  2026-06-27
# 3          BEKZAT ALMAKHAN        JEAN MATSUMOTO  2026-06-27
# 4         DANIIL DONCHENKO      THEODOR BERGGREN  2026-06-27
# 5           FARMAN HASANOV            ERIC NOLAN  2026-06-27
# 6          IKRAM ALISKEROV       BRUNNO FERREIRA  2026-06-27
# 7                KAAN OFLI          JAVIER REYES  2026-06-27
# 8           NAZIM SADYKHOV        MATHEUS CAMILO  2026-06-27
# 9       NURSULTON RUZIBOEV        ANDREY PULYAEV  2026-06-27
# 10           RAFAEL FIZIEV         MANUEL TORRES  2026-06-27
# 11         SHARA MAGOMEDOV        MICHEL PEREIRA  2026-06-27
# 12        TAHIR ABDULLAYEV  JEFFERSON NASCIMENTO  2026-06-27
#
#    red_fighter_nickname blue_fighter_nickname red_fighter_result  \
# 0            The Hunter             Juice Box                  W
# 1                   NaN                Hussar                  W
# 2              Zulfikar                InnerG                  W
# 3     The Turan Warrior                   NaN                  L
# 4                   NaN                 Simba                  W
# 5              The Lion            Night Time                  W
# 6                   NaN              The Hulk                  W
# 7               Genghis                 Blair                  W
# 8            Black Wolf                Jaguar                  L
# 9                 Black                   NaN                  W
# 10               Ataman               El Loco                  W
# 11               Bullet             Demolidor                  W
# 12                 Tank              Toddynho                  W
#
#    blue_fighter_result fight_outcome                method  round  ...  \
# 0                    L       red_win                KO/TKO      1  ...
# 1                    L       red_win            Submission      1  ...
# 2                    L       red_win            Submission      3  ...
# 3                    W      blue_win  Decision - Unanimous      3  ...
# 4                    L       red_win                KO/TKO      2  ...
# 5                    L       red_win  Decision - Unanimous      3  ...
# 6                    L       red_win  Decision - Unanimous      3  ...
# 7                    L       red_win            Submission      1  ...
# 8                    W      blue_win                KO/TKO      1  ...
# 9                    L       red_win            Submission      1  ...
# 10                   L       red_win                KO/TKO      2  ...
# 11                   L       red_win  Decision - Unanimous      3  ...
# 12                   L       red_win                KO/TKO      3  ...
#
#    blue_fighter_sig_str_distance_landed  \
# 0                                     0
# 1                                     5
# 2                                    18
# 3                                    70
# 4                                    20
# 5                                    15
# 6                                    19
# 7                                     7
# 8                                     2
# 9                                     2
# 10                                   20
# 11                                   19
# 12                                   33
#
#    blue_fighter_sig_str_distance_attempted red_fighter_sig_str_clinch_landed  \
# 0                                        1                                 0
# 1                                       19                                 1
# 2                                       41                                 1
# 3                                      211                                 4
# 4                                       60                                10
# 5                                       51                                 0
# 6                                       55                                 0
# 7                                       35                                 0
# 8                                        6                                 0
# 9                                        6                                 0
# 10                                      48                                 3
# 11                                      54                                 5
# 12                                      70                                 4
#
#    red_fighter_sig_str_clinch_attempted blue_fighter_sig_str_clinch_landed  \
# 0                                     0                                  0
# 1                                     1                                  0
# 2                                     1                                  3
# 3                                     4                                  6
# 4                                    13                                  3
# 5                                     0                                  0
# 6                                     1                                  0
# 7                                     0                                  0
# 8                                     0                                  0
# 9                                     0                                  0
# 10                                    5                                  2
# 11                                    6                                  1
# 12                                    6                                  2
#
#    blue_fighter_sig_str_clinch_attempted red_fighter_sig_str_ground_landed  \
# 0                                      0                                 5
# 1                                      0                                 0
# 2                                      4                                 9
# 3                                     14                                 0
# 4                                      4                                 0
# 5                                      0                                 2
# 6                                      0                                11
# 7                                      0                                 4
# 8                                      0                                 0
# 9                                      0                                 0
# 10                                     4                                 6
# 11                                     1                                 3
# 12                                     2                                19
#
#    red_fighter_sig_str_ground_attempted  blue_fighter_sig_str_ground_landed  \
# 0                                     7                                   0
# 1                                     1                                   0
# 2                                    13                                   0
# 3                                     0                                   3
# 4                                     1                                   0
# 5                                     4                                   0
# 6                                    13                                   0
# 7                                     5                                   0
# 8                                     0                                   2
# 9                                     0                                   0
# 10                                    7                                   0
# 11                                    4                                  15
# 12                                   26                                   0
#
#     blue_fighter_sig_str_ground_attempted
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       4
# 4                                       0
# 5                                       0
# 6                                       0
# 7                                       0
# 8                                       4
# 9                                       0
# 10                                      0
# 11                                     27
# 12                                      0
#
# [13 rows x 103 columns]
#           fighter_name height    weight reach    stance date_of_birth  slpm  \
# 0           Aalon Cruz  6' 0"  145 lbs.   78"    Switch    1989-09-20  7.58
# 1          Aaron Brink  6' 3"  205 lbs.   NaN  Orthodox    1974-11-12  3.49
# 2            Aaron Ely  5' 8"  135 lbs.   NaN       NaN    1989-03-18  0.82
# 3        Aaron Jeffery  6' 2"  185 lbs.   74"  Orthodox    1992-11-14  6.21
# 4      Aaron Lanfranco    NaN  155 lbs.   NaN       NaN    1986-08-26  0.00
# ...                ...    ...       ...   ...       ...           ...   ...
# 3768     Zhang Tiequan  5' 8"  155 lbs.   69"  Orthodox    1978-07-25  1.23
# 3769       Zhang Weili  5' 4"  115 lbs.   63"    Switch    1989-08-13  6.38
# 3770       ZHU KANGJIE  5' 6"  145 lbs.   70"  Orthodox    1996-01-16  2.93
# 3771     Zoila Frausto  5' 4"  135 lbs.   NaN  Orthodox           NaN  0.77
# 3772  Zubaira Tukhugov  5' 8"  145 lbs.   68"  Orthodox    1991-01-15  2.54
#
#      str_acc  sapm str_def  takedowns_avg takedowns_acc takedowns_def  \
# 0        39%  8.88     58%           0.00            0%            0%
# 1        42%  5.71     57%           0.00            0%            0%
# 2        15%  0.66     69%           2.47          100%           50%
# 3        84%  4.14     39%           0.00            0%           75%
# 4         0%  0.00      0%           0.00            0%            0%
# ...      ...   ...     ...            ...           ...           ...
# 3768     36%  2.14     51%           1.95           58%           75%
# 3769     45%  4.43     53%           1.26           23%          100%
# 3770     48%  1.64     66%           0.32          100%           50%
# 3771     31%  1.64     53%           0.00            0%           57%
# 3772     38%  2.53     63%           2.54           46%          100%
#
#       sub_avg  str_acc_num  takedowns_acc_num  weight_lbs  reach_inches
# 0         0.0         39.0                0.0       145.0          78.0
# 1         0.0         42.0                0.0       205.0           NaN
# 2         4.9         15.0              100.0       135.0           NaN
# 3         0.0         84.0                0.0       185.0          74.0
# 4         0.0          0.0                0.0       155.0           NaN
# ...       ...          ...                ...         ...           ...
# 3768      3.4         36.0               58.0       155.0          69.0
# 3769      0.5         45.0               23.0       115.0          63.0
# 3770      0.0         48.0              100.0       145.0          70.0
# 3771      0.0         31.0                0.0       135.0           NaN
# 3772      0.0         38.0               46.0       145.0          68.0
#
# [3773 rows x 18 columns]
#                winner_name            loser_name  event_date  \
# 0   ABDUL RAKHMAN YAKHYAEV         JULIUS WALKER  2026-06-27
# 1           ABUS MAGOMEDOV   MICHAL OLEKSIEJCZUK  2026-06-27
# 2            ASU ALMABAYEV       CHARLES JOHNSON  2026-06-27
# 3           JEAN MATSUMOTO       BEKZAT ALMAKHAN  2026-06-27
# 4         DANIIL DONCHENKO      THEODOR BERGGREN  2026-06-27
# 5           FARMAN HASANOV            ERIC NOLAN  2026-06-27
# 6          IKRAM ALISKEROV       BRUNNO FERREIRA  2026-06-27
# 7                KAAN OFLI          JAVIER REYES  2026-06-27
# 8           MATHEUS CAMILO        NAZIM SADYKHOV  2026-06-27
# 9       NURSULTON RUZIBOEV        ANDREY PULYAEV  2026-06-27
# 10           RAFAEL FIZIEV         MANUEL TORRES  2026-06-27
# 11         SHARA MAGOMEDOV        MICHEL PEREIRA  2026-06-27
# 12        TAHIR ABDULLAYEV  JEFFERSON NASCIMENTO  2026-06-27
#
#                   method  round  time        time_format  \
# 0                 KO/TKO    1.0  0:08      3 Rnd (5-5-5)
# 1             Submission    1.0  3:25      3 Rnd (5-5-5)
# 2             Submission    3.0  3:33      3 Rnd (5-5-5)
# 3   Decision - Unanimous    3.0  5:00      3 Rnd (5-5-5)
# 4                 KO/TKO    2.0  1:35      3 Rnd (5-5-5)
# 5   Decision - Unanimous    3.0  5:00      3 Rnd (5-5-5)
# 6   Decision - Unanimous    3.0  5:00      3 Rnd (5-5-5)
# 7             Submission    1.0  4:16      3 Rnd (5-5-5)
# 8                 KO/TKO    1.0  1:31      3 Rnd (5-5-5)
# 9             Submission    1.0  3:58      3 Rnd (5-5-5)
# 10                KO/TKO    2.0  0:15  5 Rnd (5-5-5-5-5)
# 11  Decision - Unanimous    3.0  5:00      3 Rnd (5-5-5)
# 12                KO/TKO    3.0  4:28      3 Rnd (5-5-5)
#
#                  bout_type                          event_name  \
# 0   Light Heavyweight Bout  UFC Fight Night: Fiziev vs. Torres
# 1        Middleweight Bout  UFC Fight Night: Fiziev vs. Torres
# 2           Flyweight Bout  UFC Fight Night: Fiziev vs. Torres
# 3        Bantamweight Bout  UFC Fight Night: Fiziev vs. Torres
# 4        Welterweight Bout  UFC Fight Night: Fiziev vs. Torres
# 5        Welterweight Bout  UFC Fight Night: Fiziev vs. Torres
# 6        Middleweight Bout  UFC Fight Night: Fiziev vs. Torres
# 7       Featherweight Bout  UFC Fight Night: Fiziev vs. Torres
# 8         Lightweight Bout  UFC Fight Night: Fiziev vs. Torres
# 9        Middleweight Bout  UFC Fight Night: Fiziev vs. Torres
# 10        Lightweight Bout  UFC Fight Night: Fiziev vs. Torres
# 11       Middleweight Bout  UFC Fight Night: Fiziev vs. Torres
# 12       Welterweight Bout  UFC Fight Night: Fiziev vs. Torres
#
#       event_location  ... delta_reach delta_slpm_cs delta_str_acc_cs  \
# 0   Baku, Azerbaijan  ...        0.00          4.92             15.0
# 1   Baku, Azerbaijan  ...       10.16         -2.67             -4.0
# 2   Baku, Azerbaijan  ...      -12.70         -2.26              2.0
# 3   Baku, Azerbaijan  ...        0.00          2.77             -1.0
# 4   Baku, Azerbaijan  ...      -10.16          4.58             27.0
# 5   Baku, Azerbaijan  ...        0.00         -0.28             17.0
# 6   Baku, Azerbaijan  ...       10.16          2.29             11.0
# 7   Baku, Azerbaijan  ...      -17.78         -3.79              0.0
# 8   Baku, Azerbaijan  ...        0.00         -2.47             -5.0
# 9   Baku, Azerbaijan  ...       -5.08         -1.22             -9.0
# 10  Baku, Azerbaijan  ...       -5.08         -1.86             -4.0
# 11  Baku, Azerbaijan  ...        0.00          1.27             11.0
# 12  Baku, Azerbaijan  ...        7.62          0.14             -6.0
#
#     delta_sapm_cs  delta_str_def_cs  delta_td_avg_cs  delta_td_acc_cs  \
# 0           -1.96              17.0             7.04             37.0
# 1           -1.11              -4.0             1.51             17.0
# 2           -1.94              -2.0             4.27             29.0
# 3            1.06              -3.0             2.85             42.0
# 4           -7.98              37.0             0.58             33.0
# 5           -1.59              26.0            17.00             62.0
# 6            0.26              -6.0             2.82             46.0
# 7            0.11              15.0            -0.93            -43.0
# 8           -2.37              17.0             3.08              8.0
# 9           -0.26              -6.0             1.09             64.0
# 10           0.57               0.0            -0.32              5.0
# 11          -0.70              -5.0            -1.11            -52.0
# 12          -0.14              -6.0             2.07             33.0
#
#     delta_td_def_cs  delta_sub_avg_cs  time_seconds
# 0               0.0               7.4             8
# 1              48.0               0.6           205
# 2             -22.0               1.0           213
# 3              -3.0               0.5           300
# 4              75.0               0.0            95
# 5             -44.0               0.0           300
# 6              50.0               0.1           300
# 7             -50.0               0.7           256
# 8             -72.0               0.4            91
# 9             -23.0               0.3           238
# 10             14.0              -0.7            15
# 11             -2.0              -0.6           300
# 12             34.0               0.0           268
#
# [13 rows x 43 columns]
#             red_fighter_name    blue_fighter_name  event_date  \
# 0     ABDUL RAKHMAN YAKHYAEV        JULIUS WALKER  2026-06-27
# 1             ABUS MAGOMEDOV  MICHAL OLEKSIEJCZUK  2026-06-27
# 2              ASU ALMABAYEV      CHARLES JOHNSON  2026-06-27
# 3            BEKZAT ALMAKHAN       JEAN MATSUMOTO  2026-06-27
# 4           DANIIL DONCHENKO     THEODOR BERGGREN  2026-06-27
# ...                      ...                  ...         ...
# 8732            ROYCE GRACIE        JASON DELUCIA  1994-03-11
# 8733            ROYCE GRACIE      MINOKI ICHIHARA  1994-03-11
# 8734            ROYCE GRACIE        PATRICK SMITH  1994-03-11
# 8735            ROYCE GRACIE        REMCO PARDOEL  1994-03-11
# 8736            SCOTT MORRIS       SEAN DAUGHERTY  1994-03-11
#
#      red_fighter_nickname blue_fighter_nickname red_fighter_result  \
# 0              The Hunter             Juice Box                  W
# 1                     NaN                Hussar                  W
# 2                Zulfikar                InnerG                  W
# 3       The Turan Warrior                   NaN                  L
# 4                     NaN                 Simba                  W
# ...                   ...                   ...                ...
# 8732                  NaN                   NaN                  W
# 8733                  NaN                   NaN                  W
# 8734                  NaN                   NaN                  W
# 8735                  NaN               Grizzly                  W
# 8736                  NaN                   NaN                  W
#
#      blue_fighter_result fight_outcome                method  round  ...  \
# 0                      L       red_win                KO/TKO      1  ...
# 1                      L       red_win            Submission      1  ...
# 2                      L       red_win            Submission      3  ...
# 3                      W      blue_win  Decision - Unanimous      3  ...
# 4                      L       red_win                KO/TKO      2  ...
# ...                  ...           ...                   ...    ...  ...
# 8732                   L       red_win            Submission      1  ...
# 8733                   L       red_win            Submission      1  ...
# 8734                   L       red_win                KO/TKO      1  ...
# 8735                   L       red_win            Submission      1  ...
# 8736                   L       red_win            Submission      1  ...
#
#      blue_fighter_sig_str_distance_landed  \
# 0                                       0
# 1                                       5
# 2                                      18
# 3                                      70
# 4                                      20
# ...                                   ...
# 8732                                    0
# 8733                                    0
# 8734                                    0
# 8735                                    0
# 8736                                    0
#
#      blue_fighter_sig_str_distance_attempted  \
# 0                                          1
# 1                                         19
# 2                                         41
# 3                                        211
# 4                                         60
# ...                                      ...
# 8732                                       0
# 8733                                       2
# 8734                                       1
# 8735                                       0
# 8736                                       3
#
#      red_fighter_sig_str_clinch_landed red_fighter_sig_str_clinch_attempted  \
# 0                                    0                                    0
# 1                                    1                                    1
# 2                                    1                                    1
# 3                                    4                                    4
# 4                                   10                                   13
# ...                                ...                                  ...
# 8732                                 0                                    0
# 8733                                 0                                    0
# 8734                                 1                                    1
# 8735                                 0                                    0
# 8736                                 1                                    1
#
#      blue_fighter_sig_str_clinch_landed blue_fighter_sig_str_clinch_attempted  \
# 0                                     0                                     0
# 1                                     0                                     0
# 2                                     3                                     4
# 3                                     6                                    14
# 4                                     3                                     4
# ...                                 ...                                   ...
# 8732                                  0                                     0
# 8733                                  0                                     0
# 8734                                  1                                     1
# 8735                                  0                                     0
# 8736                                  0                                     1
#
#      red_fighter_sig_str_ground_landed red_fighter_sig_str_ground_attempted  \
# 0                                    5                                    7
# 1                                    0                                    1
# 2                                    9                                   13
# 3                                    0                                    0
# 4                                    0                                    1
# ...                                ...                                  ...
# 8732                                 0                                    0
# 8733                                 0                                    0
# 8734                                 3                                    3
# 8735                                 0                                    0
# 8736                                 0                                    0
#
#       blue_fighter_sig_str_ground_landed  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      3
# 4                                      0
# ...                                  ...
# 8732                                   0
# 8733                                   3
# 8734                                   0
# 8735                                   0
# 8736                                   0
#
#       blue_fighter_sig_str_ground_attempted
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         4
# 4                                         0
# ...                                     ...
# 8732                                      0
# 8733                                      5
# 8734                                      0
# 8735                                      0
# 8736                                      0
#
# [8737 rows x 101 columns]

# %%
merged_stats_n_scorecards['event_date'].max()
# Out:
# '2026-06-27'

# %% [markdown]
# ### Fonte de dados
# - Local: base_dados/processed_silver/ufc_datalabs
# - Origem: https://github.com/komaksym/UFC-DataLab (projeto de coleta de dados)
# - Período coberto: eventos de 1994-03 até 2026-06
#
#
# #### Resumo
# Está bem relacionado com as duas fonte de cima porém com dados mais atualizados

# %% [markdown]
# ______________
# ### UFC fight historical

# %%
data_ufc = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\4.ufc_fight_historical\data.csv')

# %%
display(data_ufc['date'].max())
# Out:
# '2021-03-20'

# %% [markdown]
# ### Fonte de dados
# - Local: C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\4.ufc_fight_historical
# - Origem: Keagle - kaggle.com/datasets/rajeevw/ufcdata
# - Período coberto: eventos de 1994-03 até 2021-03.
#
#
# #### Resumo
# Base com dados mais antigos

# %% [markdown]
# ______________
# ### Ultimate UFC Dataset

# %%
ufc_master = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\2.ultimate_ufc_dataset\ufc_master.csv')

# %%
display(ufc_master)
# Out:
#              red_fighter      blue_fighter  red_odds  blue_odds    red_ev  \
# 0        Israel Adesanya         Joe Pyfer    -130.0      102.0   76.9231
# 1           Alexa Grasso     Maycee Barber     124.0     -158.0  124.0000
# 2         Michael Chiesa        Niko Price    -901.0      550.0   11.0988
# 3           Julian Erosa   Lerryan Douglas     235.0     -320.0  235.0000
# 4     Mansur Abdul-Malik  Yousri Belgaroui    -158.0      124.0   63.2911
# ...                  ...               ...       ...        ...       ...
# 7172        Duane Ludwig     Darren Elkins    -155.0      135.0   64.5161
# 7173         John Howard    Daniel Roberts    -210.0      175.0   47.6190
# 7174      Brendan Schaub     Chase Gormley    -260.0      220.0   38.4615
# 7175         Mike Pierce     Julio Paulino    -420.0      335.0   23.8095
# 7176        Eric Schafer       Jason Brilz     140.0     -160.0  140.0000
#
#        blue_ev        date                   location country winner  ...  \
# 0     102.0000  2026-03-28   Seattle, Washington, USA     USA   Blue  ...
# 1      63.2911  2026-03-28   Seattle, Washington, USA     USA    Red  ...
# 2     550.0000  2026-03-28   Seattle, Washington, USA     USA    Red  ...
# 3      31.2500  2026-03-28   Seattle, Washington, USA     USA   Blue  ...
# 4     124.0000  2026-03-28   Seattle, Washington, USA     USA   Blue  ...
# ...        ...         ...                        ...     ...    ...  ...
# 7172  135.0000  2010-03-21  Broomfield, Colorado, USA     USA   Blue  ...
# 7173  175.0000  2010-03-21  Broomfield, Colorado, USA     USA    Red  ...
# 7174  220.0000  2010-03-21  Broomfield, Colorado, USA     USA    Red  ...
# 7175  335.0000  2010-03-21  Broomfield, Colorado, USA     USA    Red  ...
# 7176   62.5000  2010-03-21  Broomfield, Colorado, USA     USA   Blue  ...
#
#       finish_round finish_round_time total_fight_time_secs  red_dec_odds  \
# 0              2.0              4:18                 558.0         163.0
# 1              1.0              2:42                 162.0         175.0
# 2              1.0              1:03                  63.0         225.0
# 3              1.0              3:33                 213.0         600.0
# 4              3.0              3:39                 819.0         350.0
# ...            ...               ...                   ...           ...
# 7172           1.0              0:44                  44.0           NaN
# 7173           1.0              2:01                 121.0           NaN
# 7174           1.0              0:47                  47.0           NaN
# 7175           3.0              5:00                 900.0           NaN
# 7176           3.0              5:00                 900.0           NaN
#
#       blue_dec_odds  red_sub_odds  blue_sub_odds  red_ko_odds  blue_ko_odds  \
# 0             900.0        2500.0          400.0        300.0         250.0
# 1             105.0        1400.0          800.0       2500.0         500.0
# 2             900.0        -150.0         1600.0        600.0        1000.0
# 3             500.0         600.0         2000.0        700.0        -150.0
# 4             240.0         800.0         1800.0        240.0         250.0
# ...             ...           ...            ...          ...           ...
# 7172            NaN           NaN            NaN          NaN           NaN
# 7173            NaN           NaN            NaN          NaN           NaN
# 7174            NaN           NaN            NaN          NaN           NaN
# 7175            NaN           NaN            NaN          NaN           NaN
# 7176            NaN           NaN            NaN          NaN           NaN
#
#       finish_round_time_seconds
# 0                         258.0
# 1                         162.0
# 2                          63.0
# 3                         213.0
# 4                         219.0
# ...                         ...
# 7172                       44.0
# 7173                      121.0
# 7174                       47.0
# 7175                      300.0
# 7176                      300.0
#
# [7177 rows x 119 columns]

# %% [markdown]
# ### Fonte de dados
# - Local: C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\ultimate_ufc_dataset
# - Origem: Keagle - kaggle.com/datasets/neelagiriaditya/ufc-datasets-1994-2025
# - Período coberto: eventos de 2010-03 até 2026-03.

# %% [markdown]
# ______________
# ______________
# ### `Resumo geral das nossas fontes`
#
# A partir da análise inicial das bases disponíveis, principalmente considerando atualização, cobertura temporal, riqueza de variáveis e utilidade para modelagem, definimos como fontes principais do projeto:
# - UFC-DataLab
# - scrape_ufc_stats
# - Ultimate UFC Dataset
#
# Essas bases serão priorizadas porque apresentam dados mais recentes, maior potencial analítico e melhor aderência ao objetivo do TCC, que é estruturar uma base integrada para análise e possível predição de resultados no UFC.
# As fontes que, neste primeiro momento, não serão priorizadas na exploração principal são:
# - UFC Fight Historical, por conter dados mais antigos e menor alinhamento com as bases mais recentes;
# - UFC DATASETS, por possuir cobertura limitada até 2025 e possível sobreposição com outras fontes mais completas.
#
# Apesar disso, essas fontes secundárias não serão descartadas. Elas poderão ser utilizadas de forma complementar caso apresentem variáveis relevantes que não estejam disponíveis nas bases principais. Nesse caso, será realizado um recorte compatível de período, chaves e estrutura dos dados, para incorporar essas features sem comprometer a consistência da base final.

# %% [markdown]
# --------
# --------
# --------

# %% [markdown]
# ## Construção do dataset do TCC

# %% [markdown]
# Vamos iniciar com os seguintes to do:
#
# - Entendimento das bases e identificando novas features com os 3 datasets principais
# - Identificar chaves conectando essas fontes
# - Criar desenho que conecta os dataset
# - Iniciar um EDA

# %%
# Carregar as fontes:

raw_fighter_details = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\3.ufc_datalab\raw_fighter_details.csv')

###Scrape
event_details = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\1.scrape_ufc_stats\event_details.csv')
fight_details = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\1.scrape_ufc_stats\fight_details.csv')
fight_results = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\1.scrape_ufc_stats\fight_results.csv')
fight_stats = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\1.scrape_ufc_stats\fight_stats.csv')


### dim_fighter
dim_fighter = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_silver\dim_fighters.csv')

### dim_fight

dim_fight = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_silver\dim_fight.csv')
# Out:
# C:\Users\edude\AppData\Local\Temp\ipykernel_13676\975077139.py:15: DtypeWarning: Columns (60,61,108,109,117) have mixed types. Specify dtype option on import or set low_memory=False.
#   dim_fight = pd.read_csv(r'C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_silver\dim_fight.csv')

# %% [markdown]
# ### Estrutura final ficaria desse jeito:
#
# `dim_fights` (C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_silver\dim_fight.csv)
#
#     ↓
# base central de lutas e resultados
#
# -----
#
# `fight_stats` (C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\1.scrape_ufc_stats\fight_stats.csv)
#
#     ↓
# features históricas round-a-round calculadas
#
# -----
#
# `dim_fighters` (C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_silver\dim_fighters.csv)
#
#     ↓
#
# dados físicos/cadastrais: idade, altura, peso, reach, stance
#
# -----
#
# -----
#
# `raw_fighter_details` (C:\Users\edude\OneDrive\Área de Trabalho\Códigos\Faculdade\TCC\LabA\base_dados\processed_bronze\3.ufc_datalab\raw_fighter_details.csv)
#
#     ↓
#
# validação externa, clusterização e sanity check de perfil

# %% [markdown]
# ### Chaves

# %%
dim_fighter_unique = dim_fighter.drop_duplicates(
    subset=["fighter_key"],
    keep="first"
)

# %%
fighter_id_map = dim_fighter_unique.set_index("fighter_key")["fighter_id"]

# %%
dim_fight["red_fighter_id"] = dim_fight["red_key"].map(fighter_id_map)
dim_fight["blue_fighter_id"] = dim_fight["blue_key"].map(fighter_id_map)

# %%
df_master = pd.DataFrame(dim_fight)
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8737 entries, 0 to 8736
# Columns: 150 entries, red_fighter_name to blue_fighter_id
# dtypes: float64(58), int64(44), object(48)
# memory usage: 10.0+ MB

# %%
df_master.shape
# Out:
# (8737, 150)

# %%
dados_removidos = ['red_fighter_nickname','blue_fighter_nickname','red_fighter_key','blue_fighter_key', ## Removendo dados string do lutador após termos o identificado pelo id 
'fight_outcome','time', ## Temos esses dados em outras variaveis
'referee','details' ## Informações escritas sobre a luta sem utilidade
]

df_master = df_master.drop(columns=dados_removidos, errors='ignore')

# %%
linha = df_master.iloc[500]

linha_dict = linha.to_dict()

linha_dict
# Out:
# {'red_fighter_name': 'ADAM FUGITT',
#  'blue_fighter_name': 'ISLAM DULATOV',
#  'event_date': '2025-07-19',
#  'red_fighter_result': 'L',
#  'blue_fighter_result': 'W',
#  'method': 'KO/TKO',
#  'round': 1,
#  'time_format': '3 Rnd (5-5-5)',
#  'bout_type': 'Welterweight Bout',
#  'bonus': 'perf',
#  'event_name': 'UFC 318: Holloway vs. Poirier 3',
#  'event_location': 'New Orleans, Louisiana, USA',
#  'red_fighter_kd': 0,
#  'blue_fighter_kd': 1,
#  'red_fighter_sig_str': '14 of 27',
#  'blue_fighter_sig_str': '21 of 41',
#  'red_fighter_sig_str_pct': 51.0,
#  'blue_fighter_sig_str_pct': 51.0,
#  'red_fighter_total_str': '16 of 29',
#  'blue_fighter_total_str': '23 of 44',
#  'red_fighter_td': '0 of 3',
#  'blue_fighter_td': '0 of 0',
#  'red_fighter_td_pct': 0.0,
#  'blue_fighter_td_pct': nan,
#  'red_fighter_sub_att': 0,
#  'blue_fighter_sub_att': 0,
#  'red_fighter_rev': 0,
#  'blue_fighter_rev': 0,
#  'red_fighter_ctrl': '0:59',
#  'blue_fighter_ctrl': '0:02',
#  'red_fighter_sig_str_head': '5 of 16',
#  'blue_fighter_sig_str_head': '17 of 37',
#  'red_fighter_sig_str_body': '2 of 4',
#  'blue_fighter_sig_str_body': '3 of 3',
#  'red_fighter_sig_str_leg': '7 of 7',
#  'blue_fighter_sig_str_leg': '1 of 1',
#  'red_fighter_sig_str_distance': '13 of 23',
#  'blue_fighter_sig_str_distance': '16 of 35',
#  'red_fighter_sig_str_clinch': '1 of 4',
#  'blue_fighter_sig_str_clinch': '2 of 3',
#  'red_fighter_sig_str_ground': '0 of 0',
#  'blue_fighter_sig_str_ground': '3 of 3',
#  'red_fighter_sig_str_head_pct': 35.0,
#  'blue_fighter_sig_str_head_pct': 80.0,
#  'red_fighter_sig_str_body_pct': 14.0,
#  'blue_fighter_sig_str_body_pct': 14.0,
#  'red_fighter_sig_str_leg_pct': 50.0,
#  'blue_fighter_sig_str_leg_pct': 4.0,
#  'red_fighter_sig_str_distance_pct': 92.0,
#  'blue_fighter_sig_str_distance_pct': 76.0,
#  'red_fighter_sig_str_clinch_pct': 7.0,
#  'blue_fighter_sig_str_clinch_pct': 9.0,
#  'red_fighter_sig_str_ground_pct': 0.0,
#  'blue_fighter_sig_str_ground_pct': 14.0,
#  'red_fighter_total_pts': nan,
#  'blue_fighter_total_pts': nan,
#  'time_seconds': 246,
#  'red_fighter_sig_str_landed': 14,
#  'red_fighter_sig_str_attempted': 27,
#  'blue_fighter_sig_str_landed': 21,
#  'blue_fighter_sig_str_attempted': 41,
#  'red_fighter_sig_str_pct_num': 51.0,
#  'blue_fighter_sig_str_pct_num': 51.0,
#  'red_fighter_total_str_landed': 16,
#  'red_fighter_total_str_attempted': 29,
#  'blue_fighter_total_str_landed': 23,
#  'blue_fighter_total_str_attempted': 44,
#  'red_fighter_td_landed': 0,
#  'red_fighter_td_attempted': 3,
#  'blue_fighter_td_landed': 0,
#  'blue_fighter_td_attempted': 0,
#  'red_fighter_td_pct_num': 0.0,
#  'blue_fighter_td_pct_num': nan,
#  'red_fighter_sig_str_head_landed': 5,
#  'red_fighter_sig_str_head_attempted': 16,
#  'blue_fighter_sig_str_head_landed': 17,
#  'blue_fighter_sig_str_head_attempted': 37,
#  'red_fighter_sig_str_body_landed': 2,
#  'red_fighter_sig_str_body_attempted': 4,
#  'blue_fighter_sig_str_body_landed': 3,
#  'blue_fighter_sig_str_body_attempted': 3,
#  'red_fighter_sig_str_leg_landed': 7,
#  'red_fighter_sig_str_leg_attempted': 7,
#  'blue_fighter_sig_str_leg_landed': 1,
#  'blue_fighter_sig_str_leg_attempted': 1,
#  'red_fighter_sig_str_distance_landed': 13,
#  'red_fighter_sig_str_distance_attempted': 23,
#  'blue_fighter_sig_str_distance_landed': 16,
#  'blue_fighter_sig_str_distance_attempted': 35,
#  'red_fighter_sig_str_clinch_landed': 1,
#  'red_fighter_sig_str_clinch_attempted': 4,
#  'blue_fighter_sig_str_clinch_landed': 2,
#  'blue_fighter_sig_str_clinch_attempted': 3,
#  'red_fighter_sig_str_ground_landed': 0,
#  'red_fighter_sig_str_ground_attempted': 0,
#  'blue_fighter_sig_str_ground_landed': 3,
#  'blue_fighter_sig_str_ground_attempted': 3,
#  'red_fighter_id': 'a01a62132460a98d',
#  'blue_fighter_id': 'e803242fb2e41112'}

# %%
ufc_dataset[ufc_dataset['name'].str.contains('Adam Fugitt', case=False, na=False)].to_dict()
# Out:
# {'id': {289: 'a01a62132460a98d'},
#  'name': {289: 'Adam Fugitt'},
#  'nick_name': {289: nan},
#  'wins': {289: 10},
#  'losses': {289: 5},
#  'draws': {289: 0},
#  'height': {289: 185.42},
#  'weight': {289: 77.11},
#  'reach': {289: 195.58},
#  'stance': {289: 'Southpaw'},
#  'date_of_birth': {289: nan},
#  'splm': {289: 4.59},
#  'str_acc': {289: 46},
#  'sapm': {289: 4.54},
#  'str_def': {289: 51},
#  'takedowns_avg': {289: 1.83},
#  'takedowns_avg_acc': {289: 25},
#  'takedowns_def': {289: 50},
#  'sub_avg': {289: 0.0},
#  'weight_lbs': {289: 77.11},
#  'reach_inches': {289: 195.58}}

# %%
linha = fighters_dim_final[fighters_dim_final['fighter_id']=='a01a62132460a98d'].iloc[0]
linha.to_dict()
# Out:
# {'fighter_id': 'a01a62132460a98d',
#  'fighter_key': 'ADAM FUGITT',
#  'fighter_name': 'Adam Fugitt',
#  'height': '6\' 1"',
#  'weight': '170 lbs.',
#  'reach': '77"',
#  'stance': 'Southpaw',
#  'date_of_birth': '1989-01-12',
#  'weight_lbs': 170.0,
#  'reach_inches': 77.0,
#  'height_cm': 185.42,
#  'reach_cm': 195.58,
#  'url': 'http://ufcstats.com/fighter-details/a01a62132460a98d',
#  'slpm': nan,
#  'str_acc': nan,
#  'str_acc_num': nan,
#  'sapm': nan,
#  'str_def': nan,
#  'takedowns_avg': nan,
#  'takedowns_acc': nan,
#  'takedowns_acc_num': nan,
#  'takedowns_def': nan,
#  'sub_avg': nan,
#  'source_match': 'left_only'}

# %%
df_master.dtypes.value_counts()
# Out:
# int64      44
# object     43
# float64    20
# Name: count, dtype: int64

# %%
colunas_numericas = df_master.select_dtypes(include=['int64', 'float64']).columns.tolist()
colunas_categoricas = df_master.select_dtypes(include='object').columns.tolist()

print("Numéricas:", len(colunas_numericas))
print("Categóricas:", len(colunas_categoricas))
# Out:
# Numéricas: 64
# Categóricas: 43

# %%
df_master[colunas_categoricas].describe()
# Out:
#        red_fighter_name blue_fighter_name  event_date red_fighter_nickname  \
# count              8786              8786        8786                 6334
# unique             1986              2516         774                 1141
# top          JIM MILLER       BRUNO SILVA  2016-11-19         The Predator
# freq                 37                30          25                   39
#
#        blue_fighter_nickname red_fighter_result blue_fighter_result  \
# count                   6293               8786                8786
# unique                  1372                  4                   4
# top              The Spartan                  W                   L
# freq                      39               5524                5524
#
#        fight_outcome                method  time  ...  \
# count           8786                  8786  8786  ...
# unique             4                    10   336  ...
# top          red_win  Decision - Unanimous  5:00  ...
# freq            5524                  3159  4158  ...
#
#        red_fighter_sig_str_clinch blue_fighter_sig_str_clinch  \
# count                        8786                        8786
# unique                        550                         528
# top                        0 of 0                      0 of 0
# freq                         2103                        2148
#
#        red_fighter_sig_str_ground blue_fighter_sig_str_ground  \
# count                        8786                        8786
# unique                        778                         585
# top                        0 of 0                      0 of 0
# freq                         3144                        4044
#
#        red_fighter_total_pts blue_fighter_total_pts red_fighter_key  \
# count                   2071                   2071            8786
# unique                   177                    185            1986
# top                    - - -                  - - -      JIM MILLER
# freq                     478                    478              37
#
#        blue_fighter_key    red_fighter_id   blue_fighter_id
# count              8786              8776              8781
# unique             2516              1986              2518
# top         BRUNO SILVA  d1941565abf50b16  18968f97ad34f15c
# freq                 30                37                22
#
# [4 rows x 43 columns]

# %%
df_master[colunas_numericas].describe().T
# Out:
#                                         count       mean        std  min  \
# round                                  8786.0   2.356476   1.015504  1.0
# red_fighter_kd                         8786.0   0.245846   0.517092  0.0
# blue_fighter_kd                        8786.0   0.186661   0.467239  0.0
# red_fighter_sig_str_pct                8747.0  47.927061  15.952026  0.0
# blue_fighter_sig_str_pct               8728.0  43.836503  16.749702  0.0
# ...                                       ...        ...        ...  ...
# blue_fighter_sig_str_clinch_attempted  8786.0   6.748805   9.170023  0.0
# red_fighter_sig_str_ground_landed      8786.0   5.882427   9.767132  0.0
# red_fighter_sig_str_ground_attempted   8786.0   8.516048  14.214970  0.0
# blue_fighter_sig_str_ground_landed     8786.0   3.739244   7.803343  0.0
# blue_fighter_sig_str_ground_attempted  8786.0   5.451855  10.961744  0.0
#
#                                         25%   50%   75%    max
# round                                   1.0   3.0   3.0    5.0
# red_fighter_kd                          0.0   0.0   0.0    5.0
# blue_fighter_kd                         0.0   0.0   0.0    6.0
# red_fighter_sig_str_pct                38.0  47.0  57.0  100.0
# blue_fighter_sig_str_pct               33.0  44.0  53.0  100.0
# ...                                     ...   ...   ...    ...
# blue_fighter_sig_str_clinch_attempted   1.0   3.0   9.0   89.0
# red_fighter_sig_str_ground_landed       0.0   2.0   8.0   97.0
# red_fighter_sig_str_ground_attempted    0.0   2.0  11.0  165.0
# blue_fighter_sig_str_ground_landed      0.0   0.0   4.0  136.0
# blue_fighter_sig_str_ground_attempted   0.0   1.0   6.0  163.0
#
# [64 rows x 8 columns]

# %%
nulos = df_master.isnull().sum().sort_values(ascending=False)

nulos[nulos > 0]
# Out:
# red_fighter_total_pts           6715
# blue_fighter_total_pts          6715
# bonus                           6240
# blue_fighter_td_pct_num         3282
# blue_fighter_td_pct             3282
# red_fighter_td_pct_num          2828
# red_fighter_td_pct              2828
# blue_fighter_nickname           2493
# red_fighter_nickname            2452
# blue_fighter_ctrl                181
# red_fighter_ctrl                 181
# details                           74
# blue_fighter_sig_str_pct          58
# blue_fighter_sig_str_pct_num      58
# red_fighter_sig_str_pct           39
# red_fighter_sig_str_pct_num       39
# referee                           27
# red_fighter_id                    10
# blue_fighter_id                    5
# dtype: int64
